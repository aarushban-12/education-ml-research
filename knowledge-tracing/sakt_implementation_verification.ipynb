# %% [markdown]
# # Verifying that published version of SAKT runs on local machine

# %% [markdown]
# ## Fork model form hcnoh github

# %%
# !git clone https://github.com/aarushban-12/knowledge-tracing-collection-pytorch.git
# Out:
# Cloning into 'knowledge-tracing-collection-pytorch'...
# remote: Enumerating objects: 449, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 449 (delta 0), reused 4 (delta 0), pack-reused 441 (from 1)
# Receiving objects: 100% (449/449), 1.10 MiB | 7.54 MiB/s, done.
# Resolving deltas: 100% (230/230), done.

# %%
# %cd knowledge-tracing-collection-pytorch
# Out:
# /content/knowledge-tracing-collection-pytorch

# %%
# !ls
# Out:
# assets	     data_loaders  models     requirements.txt
# config.json  LICENSE	   README.md  train.py

# %%
# !git remote -v
# Out:
# origin	https://github.com/aarushban-12/knowledge-tracing-collection-pytorch.git (fetch)
# origin	https://github.com/aarushban-12/knowledge-tracing-collection-pytorch.git (push)

# %% [markdown]
# ## Install requirements

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.2/17.2 MB 96.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 915.3/915.3 kB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 kB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.8/59.8 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 106.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Add path to dataset

# %%
# !mkdir -p datasets/ASSIST2009
# !find datasets -maxdepth 2 -type d

from google.colab import drive
drive.mount('/content/drive')
# !cp "/content/drive/MyDrive/education-ml-research/ASSISTments2009/skill_builder_data.csv" \
    "datasets/ASSIST2009/skill_builder_data.csv"
# Out:
# datasets
# datasets/ASSIST2009
# Mounted at /content/drive

# %% [markdown]
# ## Confirm dataset is in correct path

# %%
# !ls -lh datasets/ASSIST2009/
# !head -5 datasets/ASSIST2009/skill_builder_data.csv
# Out:
# total 80M
# -rw------- 1 root root 80M Aug  8 23:29 skill_builder_data.csv
# order_id,assignment_id,user_id,assistment_id,problem_id,original,correct,attempt_count,ms_first_response,tutor_mode,answer_type,sequence_id,student_class_id,position,type,base_sequence_id,skill_id,skill_name,teacher_id,school_id,hint_count,hint_total,overlap_time,template_id,answer_id,answer_text,first_action,bottom_hint,opportunity,opportunity_original
# 33022537,277618,64525,33139,51424,1,1,1,32454,tutor,algebra,5948,13241,126,MasterySection,5948,1,Box and Whisker,22763,73,0,3,32454,30799,,26,0,,1,1
# 33022709,277618,64525,33150,51435,1,1,1,4922,tutor,algebra,5948,13241,126,MasterySection,5948,1,Box and Whisker,22763,73,0,3,4922,30799,,55,0,,2,2
# 35450204,220674,70363,33159,51444,1,0,2,25390,tutor,algebra,5948,11816,22,MasterySection,5948,1,Box and Whisker,22763,73,0,3,42000,30799,,88,0,,1,1
# ...

# %% [markdown]
# ## Fix dataset encoding issue

# %%
import pandas as pd

path = "datasets/ASSIST2009/skill_builder_data.csv"

## Dataset only works in latin1, so first read in latin1 then convert to utf-8 to be used by SAKT
df = pd.read_csv(path, encoding="latin-1")

print(df.shape)
print(df.columns.tolist())

df.to_csv(
    "datasets/ASSIST2009/skill_builder_data_utf8.csv",
    index=False,
    encoding="utf-8"
)

# !mv datasets/ASSIST2009/skill_builder_data.csv datasets/ASSIST2009/skill_builder_data_original.csv
# !mv datasets/ASSIST2009/skill_builder_data_utf8.csv datasets/ASSIST2009/skill_builder_data.csv

pd.read_csv(
    "datasets/ASSIST2009/skill_builder_data.csv"
).head()
# Out:
# /tmp/ipykernel_1340/157886224.py:5: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path, encoding="latin-1")
# (525534, 30)
# ['order_id', 'assignment_id', 'user_id', 'assistment_id', 'problem_id', 'original', 'correct', 'attempt_count', 'ms_first_response', 'tutor_mode', 'answer_type', 'sequence_id', 'student_class_id', 'position', 'type', 'base_sequence_id', 'skill_id', 'skill_name', 'teacher_id', 'school_id', 'hint_count', 'hint_total', 'overlap_time', 'template_id', 'answer_id', 'answer_text', 'first_action', 'bottom_hint', 'opportunity', 'opportunity_original']
# /tmp/ipykernel_1340/157886224.py:19: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv(
#    order_id  assignment_id  user_id  assistment_id  problem_id  original  \
# 0  33022537         277618    64525          33139       51424         1
# ...

# %% [markdown]
# ## Train the model

# %%
## Confirm dataset is in correct location
# %cd /content/knowledge-tracing-collection-pytorch
# !ls -lh datasets/ASSIST2009/

## Train the model
# !python train.py --model_name=sakt --dataset_name=ASSIST2009

## Model implementation is training correctly, stopped training after 10 epochs to save time
# Out:
# /content/knowledge-tracing-collection-pytorch
# total 162M
# -rw-r--r-- 1 root root 81M Aug  8 23:37 skill_builder_data.csv
# -rw-r--r-- 1 root root 81M Aug  8 23:37 skill_builder_data_original.csv
# /content/knowledge-tracing-collection-pytorch/data_loaders/assist2009.py:58: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(self.dataset_path).dropna(subset=["skill_name"])\
# Epoch: 1,   AUC: 0.7099830812958141,   Loss Mean: 0.6238424181938171
# Epoch: 2,   AUC: 0.7540996121103245,   Loss Mean: 0.5565858483314514
# Epoch: 3,   AUC: 0.7689609855549706,   Loss Mean: 0.5336878299713135
# Epoch: 4,   AUC: 0.7779156645810658,   Loss Mean: 0.5223864316940308
# Epoch: 5,   AUC: 0.7834907268767843,   Loss Mean: 0.5149520635604858
# Epoch: 6,   AUC: 0.7882099591763854,   Loss Mean: 0.5093377828598022
# Epoch: 7,   AUC: 0.7900935556150164,   Loss Mean: 0.505475640296936
# ...

# %% [markdown]
# **SAKT implementation verification:** The original hcnoh/knowledge-tracing-collection-pytorch SAKT implementation successfully loaded the ASSISTments 2009 dataset and trained without runtime errors for multiple epochs using the repository's published hyperparameters (n=100, d=100, 5 attention heads, dropout=0.2).
